# %%
from IPython.display import Image

# %% [markdown]
# 桌面板
# 3.69G
# 1小時
# 1分鐘
# 文字版
# 1.73G
# 30分鐘
# 25秒

# %%
Image(filename="P2.jpg",width=400,height=400)

# %%
Image(filename="P3.jpg",width=400,height=400)
